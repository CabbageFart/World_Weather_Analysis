# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
         city_weather = requests.get(city_url).json()

#         # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
         city_lat = city_weather["coord"]["lat"]
         city_lng = city_weather["coord"]["lon"]
         city_max_temp = city_weather["main"]["temp_max"]
         city_humidity = city_weather["main"]["humidity"]
         city_cloudiness = city_weather["clouds"]["all"]
         city_wind = city_weather["wind"]["speed"]
         city_country = city_weather["sys"]["country"]
         city_weather_desc = city_weather["weather"][0]["description"]
        
        
#         # Convert the date to ISO standard.
#         # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
#         # Append the city information into the city_data list
         city_data.append({"City": city.title(),
                           "Lat": city_lat,
                           "Lng": city_lng,
                           "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_cloudiness,
                           "Wind Speed": city_wind,
                           "Country": city_country,
                           "Current Description": city_weather_desc
                          })
          
          #city_data.append(city_weather)
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# need to print city_weather to get weather description loc
# print(city_weather)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | boffa
# Processing Record 3 of Set 1 | gamba
# Processing Record 4 of Set 1 | ilulissat
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | westport
# Processing Record 7 of Set 1 | turukhansk
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | laguna
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | cayenne
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | maunabo
# Processing Record 15 of Set 1 | bonthe
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | robertsport
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | salalah
# Processing Record 21 of Set 1 | buraydah
# Processing Record 22 of Set 1 | jarwal
# Processing Record 23 of Set 1 | sabha
# Processing Record 24 of Set 1 | formosa
# Processing Record 25 of Set 1 | mercedes
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | ponta delgada
# Processing Record 29 of Set 1 | volchansk
# Processing Record 30 of Set 1 | desbiens
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | oranjestad
# Processing Record 33 of Set 1 | dezful
# Processing Record 34 of Set 1 | aksay
# Processing Record 35 of Set 1 | harper
# Processing Record 36 of Set 1 | narsaq
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | acarau
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | odemis
# City not found. Skipping...
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | victoria
# Processing Record 43 of Set 1 | jaciara
# Processing Record 44 of Set 1 | saint-pierre
# Processing Record 45 of Set 1 | viedma
# Processing Record 46 of Set 1 | tsienyane
# City not found. Skipping...
# Processing Record 47 of Set 1 | canapi
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | tessalit
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | bathsheba
# Processing Record 2 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 2 | totness
# Processing Record 4 of Set 2 | tiznit
# Processing Record 5 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 2 | kumher
# Processing Record 7 of Set 2 | itarema
# Processing Record 8 of Set 2 | pangnirtung
# Processing Record 9 of Set 2 | bako
# Processing Record 10 of Set 2 | ostrovnoy
# Processing Record 11 of Set 2 | mpika
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | demyanovo
# Processing Record 14 of Set 2 | atar
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | temiscaming
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | venado tuerto
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | bubaque
# Processing Record 21 of Set 2 | kochubey
# Processing Record 22 of Set 2 | kapiri mposhi
# Processing Record 23 of Set 2 | shache
# Processing Record 24 of Set 2 | sao gotardo
# Processing Record 25 of Set 2 | tabat
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | bani walid
# Processing Record 28 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | kurchum
# Processing Record 31 of Set 2 | arandis
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | preili
# Processing Record 34 of Set 2 | pauini
# Processing Record 35 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 2 | kumo
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | hambantota
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | wronki
# Processing Record 43 of Set 2 | sao filipe
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | la rioja
# Processing Record 46 of Set 2 | quatre cocos
# Processing Record 47 of Set 2 | plettenberg bay
# Processing Record 48 of Set 2 | nanortalik
# Processing Record 49 of Set 2 | quebec
# Processing Record 50 of Set 2 | sohna
# Processing Record 1 of Set 3 | bom jesus da lapa
# Processing Record 2 of Set 3 | bosaso
# Processing Record 3 of Set 3 | el wasta
# City not found. Skipping...
# Processing Record 4 of Set 3 | kalengwa
# Processing Record 5 of Set 3 | cefalu
# Processing Record 6 of Set 3 | bandarbeyla
# Processing Record 7 of Set 3 | pitimbu
# Processing Record 8 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 3 | san cristobal
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | muros
# Processing Record 12 of Set 3 | namibe
# Processing Record 13 of Set 3 | zurrieq
# Processing Record 14 of Set 3 | turtas
# Processing Record 15 of Set 3 | santa cruz cabralia
# Processing Record 16 of Set 3 | saurimo
# Processing Record 17 of Set 3 | tasiilaq
# Processing Record 18 of Set 3 | ambilobe
# Processing Record 19 of Set 3 | svetlogorsk
# Processing Record 20 of Set 3 | coquimbo
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | yelan
# Processing Record 23 of Set 3 | ramygala
# Processing Record 24 of Set 3 | port elizabeth
# Processing Record 25 of Set 3 | naumburg
# Processing Record 26 of Set 3 | luderitz
# Processing Record 27 of Set 3 | muzhi
# Processing Record 28 of Set 3 | ergani
# Processing Record 29 of Set 3 | lagoa
# Processing Record 30 of Set 3 | goderich
# Processing Record 31 of Set 3 | ostersund
# Processing Record 32 of Set 3 | mar del plata
# Processing Record 33 of Set 3 | itaituba
# Processing Record 34 of Set 3 | sakakah
# Processing Record 35 of Set 3 | arlit
# Processing Record 36 of Set 3 | ascension
# Processing Record 37 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 3 | clarksburg
# Processing Record 39 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 3 | mitu
# Processing Record 41 of Set 3 | lakshettipet
# Processing Record 42 of Set 3 | sao joao da barra
# Processing Record 43 of Set 3 | galle
# Processing Record 44 of Set 3 | uarini
# Processing Record 45 of Set 3 | bambous virieux
# Processing Record 46 of Set 3 | dire
# Processing Record 47 of Set 3 | nusaybin
# Processing Record 48 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 3 | mosquera
# Processing Record 50 of Set 3 | codrington
# Processing Record 1 of Set 4 | ust-tsilma
# Processing Record 2 of Set 4 | kruisfontein
# Processing Record 3 of Set 4 | umm lajj
# Processing Record 4 of Set 4 | rio claro
# Processing Record 5 of Set 4 | ekibastuz
# Processing Record 6 of Set 4 | saeby
# Processing Record 7 of Set 4 | touros
# Processing Record 8 of Set 4 | havre-saint-pierre
# Processing Record 9 of Set 4 | mecca
# Processing Record 10 of Set 4 | kapoeta
# Processing Record 11 of Set 4 | jumla
# Processing Record 12 of Set 4 | denizli
# Processing Record 13 of Set 4 | maragogi
# Processing Record 14 of Set 4 | punta umbria
# Processing Record 15 of Set 4 | burica
# City not found. Skipping...
# Processing Record 16 of Set 4 | vardo
# Processing Record 17 of Set 4 | sechura
# Processing Record 18 of Set 4 | ventspils
# Processing Record 19 of Set 4 | ygatimi
# Processing Record 20 of Set 4 | saint-joseph
# Processing Record 21 of Set 4 | dikson
# Processing Record 22 of Set 4 | peniche
# Processing Record 23 of Set 4 | chebarkul
# Processing Record 24 of Set 4 | karasjok
# Processing Record 25 of Set 4 | roald
# Processing Record 26 of Set 4 | yabrud
# Processing Record 27 of Set 4 | tirano
# Processing Record 28 of Set 4 | sanpaul
# Processing Record 29 of Set 4 | sao miguel do araguaia
# Processing Record 30 of Set 4 | muskegon
# Processing Record 31 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 4 | grindavik
# Processing Record 33 of Set 4 | north myrtle beach
# Processing Record 34 of Set 4 | sannicolaul mare
# City not found. Skipping...
# Processing Record 35 of Set 4 | veraval
# Processing Record 36 of Set 4 | ondarroa
# Processing Record 37 of Set 4 | george
# Processing Record 38 of Set 4 | piacabucu
# Processing Record 39 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 4 | derzhavinsk
# Processing Record 41 of Set 4 | faya
# Processing Record 42 of Set 4 | luanda
# Processing Record 43 of Set 4 | tabou
# Processing Record 44 of Set 4 | barra patuca
# Processing Record 45 of Set 4 | souillac
# Processing Record 46 of Set 4 | karsava
# Processing Record 47 of Set 4 | korla
# Processing Record 48 of Set 4 | andenes
# Processing Record 49 of Set 4 | khor
# Processing Record 50 of Set 4 | wilmington
# Processing Record 1 of Set 5 | bengkulu
# Processing Record 2 of Set 5 | munhall
# Processing Record 3 of Set 5 | tignere
# Processing Record 4 of Set 5 | pozo colorado
# Processing Record 5 of Set 5 | geraldton
# Processing Record 6 of Set 5 | manicore
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | sabang
# Processing Record 9 of Set 5 | adra
# Processing Record 10 of Set 5 | santa quiteria
# Processing Record 11 of Set 5 | ayolas
# Processing Record 12 of Set 5 | marrakesh
# Processing Record 13 of Set 5 | peterhead
# Processing Record 14 of Set 5 | el vendrell
# Processing Record 15 of Set 5 | margate
# Processing Record 16 of Set 5 | tselinnoye
# Processing Record 17 of Set 5 | bahia honda
# Processing Record 18 of Set 5 | puerto quijarro
# Processing Record 19 of Set 5 | loubomo
# Processing Record 20 of Set 5 | sol-iletsk
# Processing Record 21 of Set 5 | puerto colombia
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | axim
# Processing Record 24 of Set 5 | macaubas
# Processing Record 25 of Set 5 | coari
# Processing Record 26 of Set 5 | ornes
# Processing Record 27 of Set 5 | mahibadhoo
# Processing Record 28 of Set 5 | aksarka
# Processing Record 29 of Set 5 | coihaique
# Processing Record 30 of Set 5 | brigantine
# Processing Record 31 of Set 5 | pangody
# Processing Record 32 of Set 5 | ahtopol
# Processing Record 33 of Set 5 | manakara
# Processing Record 34 of Set 5 | kano
# Processing Record 35 of Set 5 | coronini
# Processing Record 36 of Set 5 | saint anthony
# Processing Record 37 of Set 5 | aranos
# Processing Record 38 of Set 5 | asfi
# Processing Record 39 of Set 5 | srivardhan
# Processing Record 40 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 5 | marzuq
# Processing Record 42 of Set 5 | yazd
# Processing Record 43 of Set 5 | bilma
# Processing Record 44 of Set 5 | mangrol
# Processing Record 45 of Set 5 | mitsamiouli
# Processing Record 46 of Set 5 | bereda
# Processing Record 47 of Set 5 | sept-iles
# Processing Record 48 of Set 5 | jobner
# Processing Record 49 of Set 5 | ormara
# Processing Record 50 of Set 5 | takoradi
# Processing Record 1 of Set 6 | bocana de paiwas
# Processing Record 2 of Set 6 | sao jose da coroa grande
# Processing Record 3 of Set 6 | kudahuvadhoo
# Processing Record 4 of Set 6 | santiago del estero
# Processing Record 5 of Set 6 | thinadhoo
# Processing Record 6 of Set 6 | manaure
# Processing Record 7 of Set 6 | cap malheureux
# Processing Record 8 of Set 6 | filadelfia
# Processing Record 9 of Set 6 | leh
# Processing Record 10 of Set 6 | waddan
# Processing Record 11 of Set 6 | kokkola
# Processing Record 12 of Set 6 | correntina
# Processing Record 13 of Set 6 | cochrane
# Processing Record 14 of Set 6 | daund
# Processing Record 15 of Set 6 | vila franca do campo
# Processing Record 16 of Set 6 | stornoway
# Processing Record 17 of Set 6 | kirovskiy
# Processing Record 18 of Set 6 | veseloyarsk
# Processing Record 19 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 20 of Set 6 | saint george
# Processing Record 21 of Set 6 | iranshahr
# Processing Record 22 of Set 6 | salinopolis
# Processing Record 23 of Set 6 | suceveni
# Processing Record 24 of Set 6 | adrar
# Processing Record 25 of Set 6 | porto walter
# Processing Record 26 of Set 6 | skaerbaek
# Processing Record 27 of Set 6 | borujan
# City not found. Skipping...
# Processing Record 28 of Set 6 | soyo
# Processing Record 29 of Set 6 | ouadda
# Processing Record 30 of Set 6 | murgab
# Processing Record 31 of Set 6 | cocobeach
# Processing Record 32 of Set 6 | tucuman
# Processing Record 33 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 34 of Set 6 | samaipata
# Processing Record 35 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 36 of Set 6 | hamilton
# Processing Record 37 of Set 6 | santa maria
# Processing Record 38 of Set 6 | anloga
# Processing Record 39 of Set 6 | leua
# Processing Record 40 of Set 6 | somerset west
# Processing Record 41 of Set 6 | maxixe
# Processing Record 42 of Set 6 | antigonish
# Processing Record 43 of Set 6 | awbari
# Processing Record 44 of Set 6 | debre birhan
# Processing Record 45 of Set 6 | cockburn town
# Processing Record 46 of Set 6 | igarka
# Processing Record 47 of Set 6 | gorele
# Processing Record 48 of Set 6 | cravo norte
# Processing Record 49 of Set 6 | dahra
# Processing Record 50 of Set 6 | hofn
# Processing Record 1 of Set 7 | monte carmelo
# Processing Record 2 of Set 7 | henties bay
# Processing Record 3 of Set 7 | penukonda
# Processing Record 4 of Set 7 | minna
# Processing Record 5 of Set 7 | raudeberg
# Processing Record 6 of Set 7 | irklievskaya
# City not found. Skipping...
# Processing Record 7 of Set 7 | eirunepe
# Processing Record 8 of Set 7 | zwedru
# Processing Record 9 of Set 7 | garachine
# Processing Record 10 of Set 7 | januaria
# Processing Record 11 of Set 7 | boddam
# Processing Record 12 of Set 7 | kuytun
# Processing Record 13 of Set 7 | bereznik
# Processing Record 14 of Set 7 | kavaratti
# Processing Record 15 of Set 7 | aosta
# Processing Record 16 of Set 7 | leirvik
# Processing Record 17 of Set 7 | saint-francois
# Processing Record 18 of Set 7 | tabuleiro do norte
# Processing Record 19 of Set 7 | rawson
# Processing Record 20 of Set 7 | canarana
# Processing Record 21 of Set 7 | binga
# Processing Record 22 of Set 7 | gilazi
# City not found. Skipping...
# Processing Record 23 of Set 7 | abapo
# Processing Record 24 of Set 7 | tala
# Processing Record 25 of Set 7 | hualmay
# Processing Record 26 of Set 7 | marsh harbour
# Processing Record 27 of Set 7 | qasigiannguit
# Processing Record 28 of Set 7 | malumfashi
# Processing Record 29 of Set 7 | japura
# Processing Record 30 of Set 7 | ugoofaaru
# Processing Record 31 of Set 7 | santa vitoria do palmar
# Processing Record 32 of Set 7 | teguldet
# Processing Record 33 of Set 7 | altamira
# Processing Record 34 of Set 7 | alfredo chaves
# Processing Record 35 of Set 7 | bud
# Processing Record 36 of Set 7 | dingle
# Processing Record 37 of Set 7 | beloha
# Processing Record 38 of Set 7 | sawakin
# Processing Record 39 of Set 7 | antsohihy
# Processing Record 40 of Set 7 | walvis bay
# Processing Record 41 of Set 7 | alibag
# Processing Record 42 of Set 7 | civitavecchia
# Processing Record 43 of Set 7 | san andres
# Processing Record 44 of Set 7 | puerto madryn
# Processing Record 45 of Set 7 | cartagena del chaira
# Processing Record 46 of Set 7 | skjervoy
# Processing Record 47 of Set 7 | olafsvik
# Processing Record 48 of Set 7 | shakawe
# Processing Record 49 of Set 7 | kabwe
# Processing Record 50 of Set 7 | gobabis
# Processing Record 1 of Set 8 | talca
# Processing Record 2 of Set 8 | jibuti
# Processing Record 3 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 8 | khoy
# Processing Record 5 of Set 8 | sur
# Processing Record 6 of Set 8 | barra do garcas
# Processing Record 7 of Set 8 | charkhi dadri
# Processing Record 8 of Set 8 | berlevag
# Processing Record 9 of Set 8 | sheopur
# Processing Record 10 of Set 8 | male
# Processing Record 11 of Set 8 | nalut
# Processing Record 12 of Set 8 | lachhmangarh
# Processing Record 13 of Set 8 | abu dhabi
# Processing Record 14 of Set 8 | calama
# Processing Record 15 of Set 8 | bangangte
# Processing Record 16 of Set 8 | macusani
# Processing Record 17 of Set 8 | zyryanovskiy
# City not found. Skipping...
# Processing Record 18 of Set 8 | hun
# Processing Record 19 of Set 8 | maniitsoq
# Processing Record 20 of Set 8 | navapur
# City not found. Skipping...
# Processing Record 21 of Set 8 | minab
# Processing Record 22 of Set 8 | brae
# Processing Record 23 of Set 8 | carnarvon
# Processing Record 24 of Set 8 | sambava
# Processing Record 25 of Set 8 | panaba
# Processing Record 26 of Set 8 | santiago de chuco
# Processing Record 27 of Set 8 | carballo
# Processing Record 28 of Set 8 | wladyslawowo
# Processing Record 29 of Set 8 | agadir
# Processing Record 30 of Set 8 | puerto carreno
# Processing Record 31 of Set 8 | penarroya-pueblonuevo
# Processing Record 32 of Set 8 | yar-sale
# Processing Record 33 of Set 8 | ericeira
# Processing Record 34 of Set 8 | irece
# Processing Record 35 of Set 8 | belmonte
# Processing Record 36 of Set 8 | carutapera
# Processing Record 37 of Set 8 | nouadhibou
# Processing Record 38 of Set 8 | husavik
# Processing Record 39 of Set 8 | synya
# Processing Record 40 of Set 8 | lumeje
# Processing Record 41 of Set 8 | inndyr
# Processing Record 42 of Set 8 | nieuw amsterdam
# Processing Record 43 of Set 8 | moshenskoye
# Processing Record 44 of Set 8 | los llanos de aridane
# Processing Record 45 of Set 8 | zvishavane
# Processing Record 46 of Set 8 | mahajanga
# Processing Record 47 of Set 8 | tavda
# Processing Record 48 of Set 8 | passo fundo
# Processing Record 49 of Set 8 | barroualie
# City not found. Skipping...
# Processing Record 50 of Set 8 | linares
# Processing Record 1 of Set 9 | maldonado
# Processing Record 2 of Set 9 | weiden
# Processing Record 3 of Set 9 | kalmunai
# Processing Record 4 of Set 9 | farafangana
# Processing Record 5 of Set 9 | eenhana
# Processing Record 6 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 9 | maceio
# Processing Record 8 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 9 | carbonia
# Processing Record 10 of Set 9 | matara
# Processing Record 11 of Set 9 | comodoro rivadavia
# Processing Record 12 of Set 9 | san ramon
# Processing Record 13 of Set 9 | tripoli
# Processing Record 14 of Set 9 | sabya
# Processing Record 15 of Set 9 | alta floresta
# Processing Record 16 of Set 9 | richards bay
# Processing Record 17 of Set 9 | bongandanga
# Processing Record 18 of Set 9 | paamiut
# Processing Record 19 of Set 9 | kangasala
# Processing Record 20 of Set 9 | susanino
# Processing Record 21 of Set 9 | biograd na moru
# Processing Record 22 of Set 9 | benguela
# Processing Record 23 of Set 9 | mityana
# Processing Record 24 of Set 9 | bonga
# Processing Record 25 of Set 9 | megion
# Processing Record 26 of Set 9 | puerto cabezas
# Processing Record 27 of Set 9 | honningsvag
# Processing Record 28 of Set 9 | nisia floresta
# Processing Record 29 of Set 9 | lasa
# Processing Record 30 of Set 9 | trifesti
# Processing Record 31 of Set 9 | boa vista
# Processing Record 32 of Set 9 | kalabo
# Processing Record 33 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 9 | vetlanda
# Processing Record 35 of Set 9 | itaberai
# Processing Record 36 of Set 9 | banda aceh
# Processing Record 37 of Set 9 | juan de acosta
# Processing Record 38 of Set 9 | meulaboh
# Processing Record 39 of Set 9 | mayumba
# Processing Record 40 of Set 9 | sevlievo
# Processing Record 41 of Set 9 | saint-georges
# Processing Record 42 of Set 9 | mingaora
# Processing Record 43 of Set 9 | antalaha
# Processing Record 44 of Set 9 | tabuk
# Processing Record 45 of Set 9 | abu samrah
# Processing Record 46 of Set 9 | gao
# Processing Record 47 of Set 9 | tall kayf
# Processing Record 48 of Set 9 | multan
# Processing Record 49 of Set 9 | huarmey
# Processing Record 50 of Set 9 | constantine
# Processing Record 1 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 2 of Set 10 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 3 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 10 | tres arroyos
# Processing Record 5 of Set 10 | kotaparh
# Processing Record 6 of Set 10 | moreira sales
# Processing Record 7 of Set 10 | denia
# Processing Record 8 of Set 10 | buzdyak
# Processing Record 9 of Set 10 | lunenburg
# Processing Record 10 of Set 10 | cachoeira do sul
# Processing Record 11 of Set 10 | pisco
# Processing Record 12 of Set 10 | camacha
# Processing Record 13 of Set 10 | darlowo
# Processing Record 14 of Set 10 | mpongwe
# Processing Record 15 of Set 10 | keetmanshoop
# Processing Record 16 of Set 10 | baruta
# Processing Record 17 of Set 10 | sistranda
# Processing Record 18 of Set 10 | yershov
# Processing Record 19 of Set 10 | sayyan
# Processing Record 20 of Set 10 | kondinskoye
# Processing Record 21 of Set 10 | taltal
# Processing Record 22 of Set 10 | shu
# Processing Record 23 of Set 10 | port blair
# Processing Record 24 of Set 10 | kovdor
# Processing Record 25 of Set 10 | kamenka
# Processing Record 26 of Set 10 | templin
# Processing Record 27 of Set 10 | thompson
# Processing Record 28 of Set 10 | kaka
# Processing Record 29 of Set 10 | zavetnoye
# Processing Record 30 of Set 10 | san joaquin
# Processing Record 31 of Set 10 | tacuarembo
# Processing Record 32 of Set 10 | sinnamary
# Processing Record 33 of Set 10 | fonte boa
# Processing Record 34 of Set 10 | usinsk
# Processing Record 35 of Set 10 | kostomuksha
# Processing Record 36 of Set 10 | port victoria
# Processing Record 37 of Set 10 | zhanaozen
# Processing Record 38 of Set 10 | chodziez
# Processing Record 39 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 40 of Set 10 | andros town
# Processing Record 41 of Set 10 | sable-sur-sarthe
# Processing Record 42 of Set 10 | amli
# Processing Record 43 of Set 10 | sokoto
# Processing Record 44 of Set 10 | rosario oeste
# Processing Record 45 of Set 10 | alikalia
# Processing Record 46 of Set 10 | tena
# Processing Record 47 of Set 10 | vestmanna
# Processing Record 48 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 49 of Set 10 | abha
# Processing Record 50 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 1 of Set 11 | saint-augustin
# Processing Record 2 of Set 11 | nouakchott
# Processing Record 3 of Set 11 | aksu
# Processing Record 4 of Set 11 | sisimiut
# Processing Record 5 of Set 11 | plouzane
# Processing Record 6 of Set 11 | agadez
# Processing Record 7 of Set 11 | inowroclaw
# Processing Record 8 of Set 11 | mirosov
# Processing Record 9 of Set 11 | trincomalee
# Processing Record 10 of Set 11 | den helder
# Processing Record 11 of Set 11 | la sarre
# Processing Record 12 of Set 11 | nadrag
# Processing Record 13 of Set 11 | les cayes
# Processing Record 14 of Set 11 | nioro
# Processing Record 15 of Set 11 | ginir
# Processing Record 16 of Set 11 | kadoma
# Processing Record 17 of Set 11 | asyut
# Processing Record 18 of Set 11 | porto belo
# Processing Record 19 of Set 11 | gazanjyk
# Processing Record 20 of Set 11 | umm kaddadah
# Processing Record 21 of Set 11 | beloye
# Processing Record 22 of Set 11 | brasy
# Processing Record 23 of Set 11 | dakar
# Processing Record 24 of Set 11 | emba
# Processing Record 25 of Set 11 | yaguachi
# Processing Record 26 of Set 11 | pontes e lacerda
# Processing Record 27 of Set 11 | neyshabur
# Processing Record 28 of Set 11 | pocone
# Processing Record 29 of Set 11 | celendin
# Processing Record 30 of Set 11 | tarbes
# Processing Record 31 of Set 11 | uyemskiy
# Processing Record 32 of Set 11 | plover
# Processing Record 33 of Set 11 | mabaruma
# Processing Record 34 of Set 11 | belchatow
# Processing Record 35 of Set 11 | raga
# Processing Record 36 of Set 11 | beyneu
# Processing Record 37 of Set 11 | matina
# Processing Record 38 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 39 of Set 11 | verkhnetulomskiy
# Processing Record 40 of Set 11 | hearst
# Processing Record 41 of Set 11 | kashan
# Processing Record 42 of Set 11 | san marcos de tarrazu
# City not found. Skipping...
# Processing Record 43 of Set 11 | necochea
# Processing Record 44 of Set 11 | capitao poco
# Processing Record 45 of Set 11 | santo antonio do ica
# Processing Record 46 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 47 of Set 11 | yenagoa
# Processing Record 48 of Set 11 | chapais
# Processing Record 49 of Set 11 | kozelsk
# Processing Record 50 of Set 11 | tevriz
# Processing Record 1 of Set 12 | malinovoye ozero
# Processing Record 2 of Set 12 | alice town
# Processing Record 3 of Set 12 | eyl
# Processing Record 4 of Set 12 | toamasina
# Processing Record 5 of Set 12 | mehamn
# Processing Record 6 of Set 12 | aleppo
# Processing Record 7 of Set 12 | portland
# Processing Record 8 of Set 12 | port-cartier
# Processing Record 9 of Set 12 | wad madani
# Processing Record 10 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 12 | coruripe
# Processing Record 12 of Set 12 | mezen
# Processing Record 13 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 14 of Set 12 | cascais
# Processing Record 15 of Set 12 | urvan
# Processing Record 16 of Set 12 | nurota
# Processing Record 17 of Set 12 | acurenam
# Processing Record 18 of Set 12 | mwinilunga
# Processing Record 19 of Set 12 | sao felix do xingu
# Processing Record 20 of Set 12 | el balyana
# City not found. Skipping...
# Processing Record 21 of Set 12 | ajdabiya
# Processing Record 22 of Set 12 | qandala
# Processing Record 23 of Set 12 | tazmalt
# Processing Record 24 of Set 12 | vestmannaeyjar
# Processing Record 25 of Set 12 | voronezh
# Processing Record 26 of Set 12 | grand gaube
# Processing Record 27 of Set 12 | baloda bazar
# Processing Record 28 of Set 12 | oyon
# Processing Record 29 of Set 12 | ercis
# Processing Record 30 of Set 12 | ladario
# Processing Record 31 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 12 | charlottesville
# Processing Record 33 of Set 12 | pop
# Processing Record 34 of Set 12 | metallostroy
# Processing Record 35 of Set 12 | warri
# Processing Record 36 of Set 12 | medea
# Processing Record 37 of Set 12 | riyadh
# Processing Record 38 of Set 12 | odesskoye
# Processing Record 39 of Set 12 | oistins
# Processing Record 40 of Set 12 | petrovsk
# Processing Record 41 of Set 12 | jagdalpur
# Processing Record 42 of Set 12 | waldoboro
# Processing Record 43 of Set 12 | kem
# Processing Record 44 of Set 12 | kimberley
# Processing Record 45 of Set 12 | begun
# Processing Record 46 of Set 12 | agirish
# Processing Record 47 of Set 12 | judaberg
# Processing Record 48 of Set 12 | santa fe
# Processing Record 49 of Set 12 | west bay
# Processing Record 50 of Set 12 | vikulovo
# Processing Record 1 of Set 13 | pinhao
# Processing Record 2 of Set 13 | jabinyanah
# Processing Record 3 of Set 13 | karpuninskiy
# City not found. Skipping...
# Processing Record 4 of Set 13 | daitari
# Processing Record 5 of Set 13 | coxim
# Processing Record 6 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 7 of Set 13 | qaqortoq
# Processing Record 8 of Set 13 | urumqi
# Processing Record 9 of Set 13 | gat
# Processing Record 10 of Set 13 | san ignacio
# Processing Record 11 of Set 13 | olhao
# Processing Record 12 of Set 13 | babayurt
# Processing Record 13 of Set 13 | porto novo
# Processing Record 14 of Set 13 | krasnaya gorbatka
# Processing Record 15 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 13 | ribas do rio pardo
# Processing Record 17 of Set 13 | yefremov
# Processing Record 18 of Set 13 | goure
# Processing Record 19 of Set 13 | guadalajara
# Processing Record 20 of Set 13 | kronberg
# Processing Record 21 of Set 13 | shahr-e kord
# Processing Record 22 of Set 13 | ohangaron
# Processing Record 23 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 13 | aripuana
# Processing Record 25 of Set 13 | virginia beach
# Processing Record 26 of Set 13 | itacare
# Processing Record 27 of Set 13 | nador
# Processing Record 28 of Set 13 | zyryanskoye
# Processing Record 29 of Set 13 | jacareacanga
# Processing Record 30 of Set 13 | gallipoli
# Processing Record 31 of Set 13 | chicama
# Processing Record 32 of Set 13 | koplik
# Processing Record 33 of Set 13 | gamboma
# Processing Record 34 of Set 13 | sao gabriel da cachoeira
# Processing Record 35 of Set 13 | tokzar
# City not found. Skipping...
# Processing Record 36 of Set 13 | lowestoft
# Processing Record 37 of Set 13 | gulu
# Processing Record 38 of Set 13 | kulu
# Processing Record 39 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 13 | muravlenko
# Processing Record 41 of Set 13 | luau
# Processing Record 42 of Set 13 | nottingham
# Processing Record 43 of Set 13 | syracuse
# Processing Record 44 of Set 13 | buenavista
# Processing Record 45 of Set 13 | dhidhdhoo
# Processing Record 46 of Set 13 | constitucion
# Processing Record 47 of Set 13 | vredendal
# Processing Record 48 of Set 13 | chancay
# Processing Record 49 of Set 13 | ystad
# Processing Record 50 of Set 13 | mana
# Processing Record 1 of Set 14 | port-gentil
# Processing Record 2 of Set 14 | bom jesus
# Processing Record 3 of Set 14 | slavonice
# Processing Record 4 of Set 14 | dambulla
# Processing Record 5 of Set 14 | carauari
# Processing Record 6 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 14 | inhambane
# Processing Record 8 of Set 14 | lixourion
# Processing Record 9 of Set 14 | yarada
# Processing Record 10 of Set 14 | oksovskiy
# Processing Record 11 of Set 14 | strathpeffer
# Processing Record 12 of Set 14 | rock sound
# Processing Record 13 of Set 14 | mantua
# Processing Record 14 of Set 14 | sfantu gheorghe
# Processing Record 15 of Set 14 | buzmeyin
# Processing Record 16 of Set 14 | ambanja
# Processing Record 17 of Set 14 | neya
# Processing Record 18 of Set 14 | calderitas
# Processing Record 19 of Set 14 | hurghada
# Processing Record 20 of Set 14 | zonguldak
# Processing Record 21 of Set 14 | buritizeiro
# Processing Record 22 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 14 | ilhabela
# Processing Record 24 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 14 | moose factory
# Processing Record 26 of Set 14 | khartoum
# Processing Record 27 of Set 14 | vallenar
# Processing Record 28 of Set 14 | uruzgan
# Processing Record 29 of Set 14 | miracema do tocantins
# Processing Record 30 of Set 14 | jamsa
# Processing Record 31 of Set 14 | banepa
# Processing Record 32 of Set 14 | zahirabad
# Processing Record 33 of Set 14 | vitry-le-francois
# Processing Record 34 of Set 14 | hobyo
# Processing Record 35 of Set 14 | humaita
# Processing Record 36 of Set 14 | saldanha
# Processing Record 37 of Set 14 | kirkwall
# Processing Record 38 of Set 14 | beamsville
# Processing Record 39 of Set 14 | camopi
# Processing Record 40 of Set 14 | boueni
# Processing Record 41 of Set 14 | tonj
# Processing Record 42 of Set 14 | ayagoz
# Processing Record 43 of Set 14 | monrovia
# Processing Record 44 of Set 14 | kaya
# Processing Record 45 of Set 14 | leshukonskoye
# Processing Record 46 of Set 14 | mandera
# Processing Record 47 of Set 14 | praia
# Processing Record 48 of Set 14 | umm bab
# Processing Record 49 of Set 14 | capreol
# Processing Record 50 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 1 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 2 of Set 15 | truro
# Processing Record 3 of Set 15 | sohag
# Processing Record 4 of Set 15 | dabat
# Processing Record 5 of Set 15 | qom
# Processing Record 6 of Set 15 | caravelas
# Processing Record 7 of Set 15 | talnakh
# Processing Record 8 of Set 15 | salisbury
# Processing Record 9 of Set 15 | pombas
# Processing Record 10 of Set 15 | rio gallegos
# Processing Record 11 of Set 15 | kasempa
# Processing Record 12 of Set 15 | kidal
# Processing Record 13 of Set 15 | rabo de peixe
# Processing Record 14 of Set 15 | willowmore
# Processing Record 15 of Set 15 | ornskoldsvik
# Processing Record 16 of Set 15 | lulea
# Processing Record 17 of Set 15 | longonjo
# Processing Record 18 of Set 15 | hinganghat
# Processing Record 19 of Set 15 | pocoes
# Processing Record 20 of Set 15 | hukuntsi
# Processing Record 21 of Set 15 | khabary
# Processing Record 22 of Set 15 | kitgum
# Processing Record 23 of Set 15 | aswan
# Processing Record 24 of Set 15 | lere
# Processing Record 25 of Set 15 | erzurum
# Processing Record 26 of Set 15 | hatillo
# Processing Record 27 of Set 15 | morgaushi
# Processing Record 28 of Set 15 | jutai
# Processing Record 29 of Set 15 | soria
# Processing Record 30 of Set 15 | ushtobe
# Processing Record 31 of Set 15 | liverpool
# Processing Record 32 of Set 15 | dimona
# Processing Record 33 of Set 15 | wegorzewo
# Processing Record 34 of Set 15 | nawa
# Processing Record 35 of Set 15 | paramonga
# Processing Record 36 of Set 15 | sokoni
# Processing Record 37 of Set 15 | brokopondo
# Processing Record 38 of Set 15 | bealanana
# Processing Record 39 of Set 15 | obala
# Processing Record 40 of Set 15 | sorland
# Processing Record 41 of Set 15 | bayshore gardens
# Processing Record 42 of Set 15 | canakkale
# Processing Record 43 of Set 15 | ahmadpur east
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 685

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town -33.9258   18.4232     70.09        78           0
# 1           Boffa  10.1667  -14.0333     72.61        84          78
# 2           Gamba  -2.6500   10.0000     74.34        94         100
# 3       Ilulissat  69.2167  -51.1000    -35.64        77           1
# 4        Hermanus -34.4187   19.2345     62.80        86           3
# 5        Westport  41.1415  -73.3579     40.89        90         100
# 6      Turukhansk  65.8167   87.9833    -23.53        79           9
# 7  Ribeira Grande  38.5167  -28.7000     59.77        73          75
# 8          Laguna  38.4210 -121.4238     54.14        69          40
# 9     East London -33.0153   27.9116     72.90        89          93
#
#    Wind Speed Country Current Description
# 0        9.22      ZA           clear sky
# 1        2.77      GN       broken clouds
# 2        6.82      GA       moderate rain
# 3        6.58      GL           clear sky
# 4        5.91      ZA           clear sky
# 5       10.00      US     overcast clouds
# 6       12.19      RU           clear sky
# 7       15.01      PT       broken clouds
# 8       13.80      US    scattered clouds
# 9       10.71      ZA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
new_city_df = city_data_df[new_column_order]

# Display sample data
new_city_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town      ZA -33.9258   18.4232     70.09        78           0
# 1           Boffa      GN  10.1667  -14.0333     72.61        84          78
# 2           Gamba      GA  -2.6500   10.0000     74.34        94         100
# 3       Ilulissat      GL  69.2167  -51.1000    -35.64        77           1
# 4        Hermanus      ZA -34.4187   19.2345     62.80        86           3
# 5        Westport      US  41.1415  -73.3579     40.89        90         100
# 6      Turukhansk      RU  65.8167   87.9833    -23.53        79           9
# 7  Ribeira Grande      PT  38.5167  -28.7000     59.77        73          75
# 8          Laguna      US  38.4210 -121.4238     54.14        69          40
# 9     East London      ZA -33.0153   27.9116     72.90        89          93
#
#    Wind Speed Current Description
# 0        9.22           clear sky
# 1        2.77       broken clouds
# 2        6.82       moderate rain
# 3        6.58           clear sky
# 4        5.91           clear sky
# 5       10.00     overcast clouds
# 6       12.19           clear sky
# 7       15.01       broken clouds
# 8       13.80    scattered clouds
# 9       10.71     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
new_city_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../weather_database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
new_city_df.to_csv(output_data_file, index_label="City_ID")
